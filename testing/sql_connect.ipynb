# %%
import pandas as pd
import mysql.connector
import csv

# %%
csv_file = "nba_stats_master.csv"
df = pd.read_csv(csv_file)
df_sample = df.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 csv_file = "nba_stats_master.csv"
# ----> 2 df = pd.read_csv(csv_file)
#       3 df_sample = df.head(10)
#
# ...

# %%
def insertSQL(csv_file: str, batch_size: int = 100) -> None:
    conn = mysql.connector.connect(
        host=os.("--"),
        user=os.("--"),
        password=os.("--"),
        database=os.("--")
    )
    cursor = conn.cursor()

    inserted_count = 0

    with open(csv_file, newline='') as csvfile:
        reader = csv.reader(csvfile)

        for i, row in enumerate(reader):
            if i >= batch_size:
                break

            if len(row) < 27:
                print(f"Skipping row {i+1}, not enough columns")
                continue

            row = row[:27]

            try:
                row_casted = [
                    int(row[0]),            # player_id
                    row[1],                 # season_id (VARCHAR)
                    row[2],                 # league_id (VARCHAR)
                    int(row[3]),            # team_id
                    row[4],                 # team_abbreviation (VARCHAR)

                    None if row[5] == '' else int(float(row[5])),  # player_age, use NULL if empty
                    None if row[6] == '' else int(float(row[6])),  # gp
                    None if row[7] == '' else int(float(row[7])),  # gs

                    None if row[8] == '' else float(row[8]),  # min (FLOAT) or NULL if empty

                    None if row[9] == '' else int(float(row[9])),  # fgm
                    None if row[10] == '' else int(float(row[10])), # fga
                    None if row[11] == '' else float(row[11]),  # fg_pct (FLOAT)

                    None if row[12] == '' else int(float(row[12])),  # fg3m
                    None if row[13] == '' else int(float(row[13])),  # fg3a
                    None if row[14] == '' else float(row[14]),  # fg3_pct

                    None if row[15] == '' else int(float(row[15])),  # ftm
                    None if row[16] == '' else int(float(row[16])),  # fta
                    None if row[17] == '' else float(row[17]),  # ft_pct

                    None if row[18] == '' else int(float(row[18])),  # oreb
                    None if row[19] == '' else int(float(row[19])),  # dreb
                    None if row[20] == '' else int(float(row[20])),  # reb
                    None if row[21] == '' else int(float(row[21])),  # ast
                    None if row[22] == '' else int(float(row[22])),  # stl
                    None if row[23] == '' else int(float(row[23])),  # blk
                    None if row[24] == '' else int(float(row[24])),  # tov
                    None if row[25] == '' else int(float(row[25])),  # pf
                    None if row[26] == '' else int(float(row[26])),  # pts
                ]

                # Insert row
                cursor.execute("""
                    INSERT INTO PlayerStatsRegularSeason (
                        player_id, season_id, league_id, team_id, team_abbreviation, player_age,
                        gp, gs, min, fgm, fga, fg_pct, fg3m, fg3a, fg3_pct, ftm, fta, ft_pct,
                        oreb, dreb, reb, ast, stl, blk, tov, pf, pts
                    ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
                """, row_casted)

                inserted_count += 1

            except Exception as e:
                print(f"Error inserting row {i+1} (player_id {row[0]}): {e}")
                continue

    conn.commit()
    cursor.close()
    conn.close()
    print(f"Batch insert complete: {inserted_count} rows added.")

# %%
insertSQL('nba_stats_master.csv', batch_size=1000)
