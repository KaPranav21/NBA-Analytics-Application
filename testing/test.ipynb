# %%
from nba_api.stats.endpoints import alltimeleadersgrids
import pandas as pd

# %%
alltime_stats = alltimeleadersgrids.AllTimeLeadersGrids()
alltime_stats.pts_leaders.get_json()
# Out:
# '{"headers": ["PLAYER_ID", "PLAYER_NAME", "PTS", "PTS_RANK", "IS_ACTIVE_FLAG"], "data": [[2544, "LeBron James", 42316, 1, "Y"], [76003, "Kareem Abdul-Jabbar", 38387, 2, "N"], [252, "Karl Malone", 36928, 3, "N"], [977, "Kobe Bryant", 33643, 4, "N"], [893, "Michael Jordan", 32292, 5, "N"], [1717, "Dirk Nowitzki", 31560, 6, "N"], [76375, "Wilt Chamberlain", 31419, 7, "N"], [201142, "Kevin Durant", 31067, 8, "Y"], [406, "Shaquille O\'Neal", 28596, 9, "N"], [201935, "James Harden", 28325, 10, "Y"]]}'

# %%
pts_leaders_df = alltime_stats.pts_leaders.get_data_frame()
pts_leaders_df
# Out:
#    PLAYER_ID          PLAYER_NAME    PTS  PTS_RANK IS_ACTIVE_FLAG
# 0       2544         LeBron James  42316         1              Y
# 1      76003  Kareem Abdul-Jabbar  38387         2              N
# 2        252          Karl Malone  36928         3              N
# 3        977          Kobe Bryant  33643         4              N
# 4        893       Michael Jordan  32292         5              N
# 5       1717        Dirk Nowitzki  31560         6              N
# 6      76375     Wilt Chamberlain  31419         7              N
# 7     201142         Kevin Durant  31067         8              Y
# 8        406     Shaquille O'Neal  28596         9              N
# 9     201935         James Harden  28325        10              Y
